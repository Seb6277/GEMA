# %% [markdown]
# # Regression a noyaux

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression

plt.rcParams.update({
    'font.size': 25,
    'figure.figsize': (25, 5)
})

# %%
# Le contenu de cette cellule est inconnue en pratique
size = 1000

x = np.linspace(start=0, stop=3, num=size)
y = np.square(x) + np.random.normal(size=len(x))*0.3
y = np.where(y>0, y, 0)

# %% [markdown]
# ## Analyse de la base de donnée

# %% [markdown]
# On plot $x$ et $y$

# %%
plt.plot(x, y, 'x')
plt.xlabel('x')
plt.ylabel('y')
plt.show()

# %% [markdown]
# ## Regression linéaire
# C'est la méthode naive, on applique simplement une regression linéire sur nos données.

# %%
def fit_regression(X, y):
    # Reshape input for sklearn
    if len(X.shape) < 2:
        X = x.reshape(-1, 1)
    
    # Fit regression
    model = LinearRegression()
    reg = model.fit(X, y)
    
    # Compute score
    print(f"Regression score: {reg.score(X, y)}")
    
    # Plot real data
    plt.plot(x, y, 'x', label='data')
    # Plot regression line
    plt.plot(x, reg.predict(X), lw=5, label='regression')
    
    return reg

# %%
reg = fit_regression(x, y)
plt.xlabel('x')
plt.ylabel('y')
plt.legend()
plt.show()

print(f"y = {reg.coef_.round(2).item()} * x + {reg.intercept_.round(2).item()}")
# Out:
# Regression score: 0.9222808464716661
# y = 2.98 * x + -1.46

# %% [markdown]
# Comme on s'y attendais, ça ne donne rien !

# %% [markdown]
# ## Méthode 1: Modifier les données
# On va appliquer une fonction **non linéaire** aux données, pour les rendres plus facilement interprétable. On applique par exemple une fonction racine carré $z = \sqrt y$.

# %%
z = np.sqrt(y)

plt.plot(x, z, 'x')
plt.xlabel('x')
plt.ylabel('z')
plt.show()

# %% [markdown]
# Puis on relance notre regression lineaire, avec $z$

# %%
reg = fit_regression(x, z)
plt.xlabel('x')
plt.ylabel('z')
plt.legend()
plt.show()
# Out:
# Regression score: 0.9646845534300073

# %% [markdown]
# On applique maintenant la fonction de **transformation inverse** sur notre regression

# %%
plt.plot(x, y, 'x', label='data')
plt.plot(x, np.square(reg.predict(x.reshape(-1, 1))), lw=5, label='regression noyau')
plt.legend()
plt.show()

# %% [markdown]
# ## Méthode 2: Développer les variables d'entrée

# %%
X = np.stack([
    x,
    x*x,
]).T

reg = fit_regression(X, y)
plt.xlabel('x')
plt.ylabel('y')
plt.legend()
plt.show()

print(f"Les coefficients de regression sont {reg.coef_}")
# Out:
# Regression score: 0.9891212731192318
# Les coefficients de regression sont [-0.11075881  1.02695255]

# %% [markdown]
# ### En bonus, la méthode à l'arache

# %%
X = np.stack([
    x,
    x*x,
    x*x*x,
    np.sqrt(x),
    np.exp(x)
]).T

plt.plot(X)
plt.show()

# %%
reg = fit_regression(X, y)
plt.xlabel('x')
plt.ylabel('y')
plt.legend()
plt.show()

print(f"Les coefficients de regression sont {reg.coef_}")
# Out:
# Regression score: 0.9892370959702403
# Les coefficients de regression sont [-0.56802064  1.34926345 -0.09558323  0.05132425  0.04322935]
